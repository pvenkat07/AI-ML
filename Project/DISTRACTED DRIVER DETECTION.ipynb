# %%
# #importing data set 
import os
# import zipfile
# local_zip = "../Project/state-farm-distracted-driver-detection.zip"
# zip_ref = zipfile.ZipFile(local_zip,'r')
# zip_ref.extractall('../Project/Dataset')
# zip_ref.close()

# %%
# displaying folder names in the data set
print("Folders in data set : ",os.listdir("../Project/Dataset"))
# Out:
# Folders in data set :  ['imgs', 'driver_imgs_list.csv', 'sample_submission.csv']

# %%
# Checking versions of required packages
import tensorflow
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print(tensorflow.__version__)
print(pd.__version__)
print(np.__version__)
print(sns.__version__)
# %matplotlib inline
# Out:
# 2.2.0
# 1.0.1
# 1.18.1
# 0.10.0

# %%
#printing folders in training data 
print(os.listdir('../Project/Dataset/imgs/train'))
# Out:
# ['c7', 'c1', 'c4', 'c0', 'c6', 'c9', 'c8', 'c2', 'c5', 'c3']

# %%
# printing no of files in each folder
for k in os.listdir('../Project/Dataset/imgs/train'):
    num_files = len(os.listdir('../Project/Dataset/imgs/train/'+i))
    print("{} : {}".format(k, num_files))
# Out:
# c7 : 2346
# c1 : 2346
# c4 : 2346
# c0 : 2346
# c6 : 2346
# c9 : 2346
# c8 : 2346
# c2 : 2346
# c5 : 2346
# c3 : 2346

# %%
# Printing the length of test data set
print(len(os.listdir('../Project/Dataset/imgs/test')))
# Out:
# 79726

# %%
base_dir = "../Project/Dataset/imgs"
train_dir = os.path.join(base_dir,'train')
validation_dir = os.path.join(base_dir,'validation')
## Directory with training each cotegory of from c1 to c9 pictures
train_0_dir = os.path.join(train_dir,'c0')
train_1_dir = os.path.join(train_dir,'c1')
train_2_dir = os.path.join(train_dir,'c2')
train_3_dir = os.path.join(train_dir,'c3')
train_4_dir = os.path.join(train_dir,'c4')
train_5_dir = os.path.join(train_dir,'c5')
train_6_dir = os.path.join(train_dir,'c6')
train_7_dir = os.path.join(train_dir,'c7')
train_8_dir = os.path.join(train_dir,'c8')
train_9_dir = os.path.join(train_dir,'c9')
## Directory with testing each cotegory of from c1 to c9 picture
validation_0_dir = os.path.join(validation_dir,'c0')
validation_1_dir = os.path.join(validation_dir,'c1')
validation_2_dir = os.path.join(validation_dir,'c2')
validation_3_dir = os.path.join(validation_dir,'c3')
validation_4_dir = os.path.join(validation_dir,'c4')
validation_5_dir = os.path.join(validation_dir,'c5')
validation_6_dir = os.path.join(validation_dir,'c6')
validation_7_dir = os.path.join(validation_dir,'c7')
validation_8_dir = os.path.join(validation_dir,'c8')
validation_9_dir = os.path.join(validation_dir,'c9')

# %%
train_0_filenames = os.listdir(train_0_dir )
train_0_filenames[:4]
# Out:
# ['img_8319.jpg', 'img_18619.jpg', 'img_71138.jpg', 'img_81205.jpg']

# %%
plt.imshow(plt.imread(train_0_dir+'/img_18619.jpg'))

# %%
plt.figure(figsize=(16,16))
j = 1  ## plot position
for i in range(16):
  img = plt.imread(os.path.join(train_0_dir,train_0_filenames[i]))
  plt.subplot(4,4,j)
  plt.imshow(img)
  plt.title(img.shape)
  plt.axis('off')
  j += 1
