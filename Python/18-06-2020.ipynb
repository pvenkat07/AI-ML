# %%
# importinfg the requred libraries
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
# %matplotlib inline

# %%
# Reading data set
df = pd.read_csv(r"titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#identifing missing values count
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#checking unique values
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df.describe(include=['object'])
# Out:
#                               Name   Sex    Ticket    Cabin Embarked
# count                          891   891       891      204      889
# unique                         891     2       681      147        3
# top     Chapman, Mr. Charles Henry  male  CA. 2343  B96 B98        S
# freq                             1   577         7        4      644

# %%
sns.heatmap(df.isna())

# %%
import missingno as msno
msno.matrix(df)

# %%
msno.bar(df)

# %%
df.hist(figsize=(12,12))
plt.show()

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.Survived.value_counts(normalize=True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
sns.countplot(df['Survived'])

# %%
(df.Survived.value_counts(normalize=True)*100).plot.barh()

# %%
df['Survived'][df['Sex']=='female'].value_counts()
# Out:
# 1    233
# 0     81
# Name: Survived, dtype: int64

# %%
df['Survived'][df['Sex']=='male'].value_counts()
# Out:
# 0    468
# 1    109
# Name: Survived, dtype: int64

# %%
sns.barplot(x = 'Sex',y ='Survived',data =df)

# %%
sns.barplot(x='Survived',y='SibSp',data =df)

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df.isnull().mean().sort_values(ascending=False)
# Out:
# Cabin          0.771044
# Age            0.198653
# Embarked       0.002245
# Fare           0.000000
# Ticket         0.000000
# Parch          0.000000
# SibSp          0.000000
# Sex            0.000000
# Name           0.000000
# Pclass         0.000000
# Survived       0.000000
# PassengerId    0.000000
# dtype: float64

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df.Age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64

# %%
df['Age_Ranfe'] = pd.cut(df.Age,[0,10,20,30,40,50,60,70,80])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import numpy as np

arr = np.array([1, 3, 2, 4, 5])

print(arr.argsort()[-3:][::-1])
# Out:
# [4 3 1]
